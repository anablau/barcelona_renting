# %%
import seaborn as sns 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df15 = pd.read_csv("2015_lloguer_preu_trim.csv")

# %%
df15.head()
# Out:
#     Any  Trimestre  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2015          1               1  Ciutat Vella           1
# 1  2015          1               1  Ciutat Vella           2
# 2  2015          1               1  Ciutat Vella           3
# 3  2015          1               1  Ciutat Vella           4
# 4  2015          1               2      Eixample           5
#
#                                Nom_Barri                      Lloguer_mitja  \
# 0                               el Raval  Lloguer mitjà mensual (Euros/mes)
# 1                         el Barri Gòtic  Lloguer mitjà mensual (Euros/mes)
# 2                         la Barceloneta  Lloguer mitjà mensual (Euros/mes)
# 3  Sant Pere, Santa Caterina i la Ribera  Lloguer mitjà mensual (Euros/mes)
# 4                          el Fort Pienc  Lloguer mitjà mensual (Euros/mes)
#
#      Preu
# 0  601.31
# 1  756.68
# 2  581.34
# 3  697.16
# 4  753.76

# %%
df15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584 entries, 0 to 583
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Any             584 non-null    int64
#  1   Trimestre       584 non-null    int64
#  2   Codi_Districte  584 non-null    int64
#  3   Nom_Districte   584 non-null    object
#  4   Codi_Barri      584 non-null    int64
#  5   Nom_Barri       584 non-null    object
#  6   Lloguer_mitja   584 non-null    object
#  7   Preu            552 non-null    float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 36.6+ KB

# %%
df16 = pd.read_csv("2016_lloguer_preu_trim.csv")

# %%
df17 = pd.read_csv("2017_lloguer_preu_trim.csv")

# %%
df18 = pd.read_csv("2018_lloguer_preu_trim.csv")

# %%
df19 = pd.read_csv("2019_lloguer_preu_trim.csv")

# %%
df20 = pd.read_csv("2020_lloguer_preu_trim.csv")

# %%
df=pd.concat([df15,df16,df17,df18,df19,df20],axis=0)

# %%
df
# Out:
#       Any  Trimestre  Codi_Districte Nom_Districte  Codi_Barri  \
# 0    2015          1               1  Ciutat Vella           1
# 1    2015          1               1  Ciutat Vella           2
# 2    2015          1               1  Ciutat Vella           3
# 3    2015          1               1  Ciutat Vella           4
# 4    2015          1               2      Eixample           5
# ..    ...        ...             ...           ...         ...
# 287  2020          2              10    Sant Martí          69
# 288  2020          2              10    Sant Martí          70
# 289  2020          2              10    Sant Martí          71
# 290  2020          2              10    Sant Martí          72
# 291  2020          2              10    Sant Martí          73
#
#                                         Nom_Barri  \
# 0                                        el Raval
# 1                                  el Barri Gòtic
# 2                                  la Barceloneta
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3212 entries, 0 to 291
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Any             3212 non-null   int64
#  1   Trimestre       3212 non-null   int64
#  2   Codi_Districte  3212 non-null   int64
#  3   Nom_Districte   3212 non-null   object
#  4   Codi_Barri      3212 non-null   int64
#  5   Nom_Barri       3212 non-null   object
#  6   Lloguer_mitja   3212 non-null   object
#  7   Preu            2999 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 225.8+ KB

# %%
df1 = df[df.isna().any(axis=1)]

# %%
df1
# Out:
#       Any  Trimestre  Codi_Districte   Nom_Districte  Codi_Barri  \
# 11   2015          1               3  Sants-Montjuïc          12
# 41   2015          1               7  Horta-Guinardó          42
# 46   2015          1               8      Nou Barris          47
# 48   2015          1               8      Nou Barris          49
# 53   2015          1               8      Nou Barris          54
# ..    ...        ...             ...             ...         ...
# 265  2020          2               8      Nou Barris          47
# 267  2020          2               8      Nou Barris          49
# 272  2020          2               8      Nou Barris          54
# 274  2020          2               8      Nou Barris          56
# 276  2020          2               9     Sant Andreu          58
#
#                       Nom_Barri                                Lloguer_mitja  \
# 11   la Marina del Prat Vermell            Lloguer mitjà mensual (Euros/mes)
# ...

# %%
df=df.dropna()

# %%
monthly=df[df['Lloguer_mitja'] == 'Lloguer mitjà mensual (Euros/mes)']

# %%
surface=df[df['Lloguer_mitja'] == 'Lloguer mitjà per superfície (Euros/m2 mes)']

# %%
monthly
# Out:
#       Any  Trimestre  Codi_Districte Nom_Districte  Codi_Barri  \
# 0    2015          1               1  Ciutat Vella           1
# 1    2015          1               1  Ciutat Vella           2
# 2    2015          1               1  Ciutat Vella           3
# 3    2015          1               1  Ciutat Vella           4
# 4    2015          1               2      Eixample           5
# ..    ...        ...             ...           ...         ...
# 214  2020          2              10    Sant Martí          69
# 215  2020          2              10    Sant Martí          70
# 216  2020          2              10    Sant Martí          71
# 217  2020          2              10    Sant Martí          72
# 218  2020          2              10    Sant Martí          73
#
#                                         Nom_Barri  \
# 0                                        el Raval
# 1                                  el Barri Gòtic
# 2                                  la Barceloneta
# ...

# %%
surface
# Out:
#       Any  Trimestre  Codi_Districte Nom_Districte  Codi_Barri  \
# 292  2015          1               1  Ciutat Vella           1
# 293  2015          1               1  Ciutat Vella           2
# 294  2015          1               1  Ciutat Vella           3
# 295  2015          1               1  Ciutat Vella           4
# 296  2015          1               2      Eixample           5
# ..    ...        ...             ...           ...         ...
# 287  2020          2              10    Sant Martí          69
# 288  2020          2              10    Sant Martí          70
# 289  2020          2              10    Sant Martí          71
# 290  2020          2              10    Sant Martí          72
# 291  2020          2              10    Sant Martí          73
#
#                                         Nom_Barri  \
# 292                                      el Raval
# 293                                el Barri Gòtic
# 294                                la Barceloneta
# ...

# %%
a = monthly.groupby(by=["Any", "Nom_Districte"])["Preu"].mean().reset_index()

# %%
d=a.groupby(by=["Any"])["Preu"].mean().reset_index()

# %%
b=a[a['Any'] == 2015]

# %%
c=a[a['Any'] == 2020]

# %%
c
# Out:
#      Any        Nom_Districte         Preu
# 50  2020         Ciutat Vella   940.600000
# 51  2020             Eixample  1077.883333
# 52  2020               Gràcia   952.180000
# 53  2020       Horta-Guinardó   812.425000
# 54  2020            Les Corts  1256.166667
# 55  2020           Nou Barris   648.090000
# 56  2020          Sant Andreu   757.923077
# 57  2020           Sant Martí   954.435000
# 58  2020       Sants-Montjuïc   844.642857
# 59  2020  Sarrià-Sant Gervasi  1319.283333

# %%
plt.figure(figsize=(10,6))
# make barplot and sort bars
chart=sns.barplot(x='Nom_Districte',
            y="Preu", 
            data=c, 
            order=c.sort_values('Preu').Nom_Districte,palette='Reds')
# set labels
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.xlabel("Districts", size=15,)
plt.ylabel("Average Monthly Rent", size=15)
plt.title("Montly District Rent in Ascending Order in 2020", size=18)
plt.tight_layout()
plt.savefig("sort_bars_in_barplot_ascending_order_Seaborn_Python.png", dpi=100)

# %%
plt.figure(figsize=(10,6))
# make barplot and sort bars
chart=sns.barplot(x='Nom_Districte',
            y="Preu", 
            data=b, 
            order=b.sort_values('Preu').Nom_Districte,palette='Greens')
# set labels
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.xlabel("Districts", size=15,)
plt.ylabel("Average Monthly Rent", size=15)
plt.title("Montly District Rent in Ascending Order in 2015", size=18)
plt.tight_layout()
plt.savefig("sort_bars_in_barplot_ascending_order_Seaborn_Python.png", dpi=100)

# %%
d
# Out:
#     Any        Preu
# 0  2015  738.027417
# 1  2016  795.605937
# 2  2017  877.766675
# 3  2018  917.030324
# 4  2019  967.066070
# 5  2020  956.362927

# %%
e=surface.groupby(by=["Any"])["Preu"].mean().reset_index()

# %%
e
# Out:
#     Any       Preu
# 0  2015  10.453043
# 1  2016  11.494239
# 2  2017  12.638059
# 3  2018  12.819444
# 4  2019  13.374349
# 5  2020  13.276296

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=d, x="Any", y="Preu",linewidth = 4,color='#0550D0')
plt.xlabel("Year", size=15,)
plt.ylabel("Average Rent", size=15)
plt.title("Average Rent per Year", size=18)
# Out:
# Text(0.5, 1.0, 'Average Rent per Year')

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=e, x="Any", y="Preu",linewidth = 4,color='orange')
plt.xlabel("Year", size=15,)
plt.ylabel("Average Value per m2", size=15)
plt.title("Average Value per m2 per Year", size=18)

#max rent in 2019
# Out:
# Text(0.5, 1.0, 'Average Value per m2 per Year')

# %%
nom_barri_m = monthly.groupby(by=["Any","Nom_Barri"])["Preu"].mean().reset_index()

# %%
nom_barri_s = surface.groupby(by=["Any","Nom_Barri"])["Preu"].mean().reset_index()

# %%
nom_barri_m
# Out:
#       Any                                     Nom_Barri       Preu
# 0    2015                                 Baró de Viver   284.5800
# 1    2015                                      Can Baró   549.2775
# 2    2015                                     Canyelles   577.2900
# 3    2015                              Ciutat Meridiana   395.4125
# 4    2015  Diagonal Mar i el Front Marítim del Poblenou  1032.6550
# ..    ...                                           ...        ...
# 415  2020                 la Vila Olímpica del Poblenou  1436.8000
# 416  2020                             la Vila de Gràcia   955.9500
# 417  2020                                     les Corts  1083.2500
# 418  2020                                  les Roquetes   609.6500
# 419  2020                               les Tres Torres  1670.7500
#
# [420 rows x 3 columns]

# %%
nom_barrim2020=nom_barri_m [nom_barri_m ['Any'] == 2020]

# %%
nom_barrim2020
# Out:
#       Any                                     Nom_Barri     Preu
# 351  2020                                 Baró de Viver   584.10
# 352  2020                                      Can Baró   777.85
# 353  2020                                     Canyelles   778.00
# 354  2020                              Ciutat Meridiana   506.95
# 355  2020  Diagonal Mar i el Front Marítim del Poblenou  1037.05
# ..    ...                                           ...      ...
# 415  2020                 la Vila Olímpica del Poblenou  1436.80
# 416  2020                             la Vila de Gràcia   955.95
# 417  2020                                     les Corts  1083.25
# 418  2020                                  les Roquetes   609.65
# 419  2020                               les Tres Torres  1670.75
#
# [69 rows x 3 columns]

# %%
nom_barrim2020sorted=nom_barrim2020.sort_values(by=['Preu'], ascending=False)

# %%
nom_barrim2020sorted
# Out:
#       Any                      Nom_Barri     Preu
# 360  2020                      Pedralbes  1724.80
# 419  2020                les Tres Torres  1670.75
# 415  2020  la Vila Olímpica del Poblenou  1436.80
# 372  2020                         Sarrià  1417.20
# 366  2020         Sant Gervasi - Galvany  1344.10
# ..    ...                            ...      ...
# 418  2020                   les Roquetes   609.65
# 351  2020                  Baró de Viver   584.10
# 411  2020               la Trinitat Nova   544.10
# 354  2020               Ciutat Meridiana   506.95
# 373  2020                     Torre Baró   452.00
#
# [69 rows x 3 columns]

# %%
expandcheapbarris=nom_barrim2020sorted.iloc[np.r_[0:5, -5:0]]

# %%
expandcheapbarris
# Out:
#       Any                      Nom_Barri     Preu
# 360  2020                      Pedralbes  1724.80
# 419  2020                les Tres Torres  1670.75
# 415  2020  la Vila Olímpica del Poblenou  1436.80
# 372  2020                         Sarrià  1417.20
# 366  2020         Sant Gervasi - Galvany  1344.10
# 418  2020                   les Roquetes   609.65
# 351  2020                  Baró de Viver   584.10
# 411  2020               la Trinitat Nova   544.10
# 354  2020               Ciutat Meridiana   506.95
# 373  2020                     Torre Baró   452.00

# %%
plt.figure(figsize=(10,8))
# make barplot and sort bars
chart=sns.barplot(x='Nom_Barri',
            y="Preu", 
            data=expandcheapbarris, 
            order=expandcheapbarris.sort_values('Preu').Nom_Barri,palette='magma')
# set labels
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.xlabel("Barris", size=15,)
plt.ylabel("Average Montly Rent", size=15)
plt.title("Most expensive and cheap Barris in 2020", size=18)
plt.tight_layout()

# %%
nom_barrim2015=nom_barri_m [nom_barri_m ['Any'] == 2015]

# %%
nom_barrim2015sorted=nom_barrim2015.sort_values(by=['Preu'], ascending=False)
expandcheapbarris15=nom_barrim2015sorted.iloc[np.r_[0:5, -5:0]]

# %%
plt.figure(figsize=(10,8))
# make barplot and sort bars
chart=sns.barplot(x='Nom_Barri',
            y="Preu", 
            data=expandcheapbarris15, 
            order=expandcheapbarris15.sort_values('Preu').Nom_Barri,palette='cubehelix')
# set labels
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.xlabel("Barris", size=15,)
plt.ylabel("Average Montly Rent", size=15)
plt.title("Most expensive and cheap Barris in 2015", size=18)
plt.tight_layout()

# %%
sns.distplot(monthly['Preu'])
# Out:
# <AxesSubplot:xlabel='Preu'>

# %%
k=monthly[monthly['Any'] == 2015]
l=monthly[monthly['Any'] == 2016]
m=monthly[monthly['Any'] == 2017]
n=monthly[monthly['Any'] == 2018]
o=monthly[monthly['Any'] == 2019]
p=monthly[monthly['Any'] == 2020]

# %%
plt.figure(figsize=(20, 12))
plt.title('Monthly Average Rent Distribution Per Year')
plt.subplot(331)
sns.distplot(k['Preu'])
plt.xlabel("2015",size = 13)
plt.ylabel("Price",size = 13)

plt.subplot(332)
sns.distplot(l['Preu'])
plt.xlabel("2016",size = 13)
plt.ylabel("Price",size = 13)

plt.subplot(333)
sns.distplot(m['Preu'])
plt.xlabel("2017",size = 13)
plt.ylabel("Price",size = 13)

plt.subplot(334)
sns.distplot(n['Preu'])
plt.xlabel("2018",size = 13)
plt.ylabel("Price",size = 13)

plt.subplot(335)
sns.distplot(o['Preu'])
plt.xlabel("2019",size = 13)
plt.ylabel("Price",size = 13)

plt.subplot(336)
sns.distplot(p['Preu'])
plt.xlabel("2020",size = 13)
plt.ylabel("Price",size = 13)
# Out:
# Text(0, 0.5, 'Price')

# %%
sns.distplot(surface['Preu'])
# Out:
# <AxesSubplot:xlabel='Preu'>

# %%
surface.describe()
# Out:
#                Any    Trimestre  Codi_Districte   Codi_Barri         Preu
# count  1499.000000  1499.000000     1499.000000  1499.000000  1499.000000
# mean   2017.256838     2.409606        6.185457    36.493662    12.247425
# std       1.601509     1.115644        2.830603    21.332054     2.415491
# min    2015.000000     1.000000        1.000000     1.000000     3.180000
# 25%    2016.000000     1.000000        3.000000    18.000000    10.685000
# 50%    2017.000000     2.000000        7.000000    35.000000    12.200000
# 75%    2019.000000     3.000000        8.000000    55.000000    13.845000
# max    2020.000000     4.000000       10.000000    73.000000    20.900000

# %%
monthly.describe()
# Out:
#                Any    Trimestre  Codi_Districte   Codi_Barri         Preu
# count  1500.000000  1500.000000     1500.000000  1500.000000  1500.000000
# mean   2017.256000     2.410000        6.186667    36.505333   822.177560
# std       1.601304     1.115376        2.830046    21.329728   258.191379
# min    2015.000000     1.000000        1.000000     1.000000     0.000000
# 25%    2016.000000     1.000000        3.000000    18.000000   658.345000
# 50%    2017.000000     2.000000        7.000000    35.000000   774.675000
# 75%    2019.000000     3.000000        8.000000    55.000000   924.202500
# max    2020.000000     4.000000       10.000000    73.000000  2034.000000

# %%
monthly
# Out:
#       Any  Trimestre  Codi_Districte Nom_Districte  Codi_Barri  \
# 0    2015          1               1  Ciutat Vella           1
# 1    2015          1               1  Ciutat Vella           2
# 2    2015          1               1  Ciutat Vella           3
# 3    2015          1               1  Ciutat Vella           4
# 4    2015          1               2      Eixample           5
# ..    ...        ...             ...           ...         ...
# 214  2020          2              10    Sant Martí          69
# 215  2020          2              10    Sant Martí          70
# 216  2020          2              10    Sant Martí          71
# 217  2020          2              10    Sant Martí          72
# 218  2020          2              10    Sant Martí          73
#
#                                         Nom_Barri  \
# 0                                        el Raval
# 1                                  el Barri Gòtic
# 2                                  la Barceloneta
# ...

# %%
z= monthly

# %%
z=z.drop(['Nom_Districte', 'Nom_Barri','Lloguer_mitja'], axis = 1)

# %%
z.corr()
# Out:
#                      Any  Trimestre  Codi_Districte  Codi_Barri      Preu
# Any             1.000000  -0.139110       -0.004222   -0.005040  0.316203
# Trimestre      -0.139110   1.000000       -0.001437   -0.001957  0.037605
# Codi_Districte -0.004222  -0.001437        1.000000    0.980800 -0.285201
# Codi_Barri     -0.005040  -0.001957        0.980800    1.000000 -0.291611
# Preu            0.316203   0.037605       -0.285201   -0.291611  1.000000

# %%
corrMatrix = z.corr()
sns.heatmap(corrMatrix, annot = True, vmin=-1, vmax=1, center= 0)
plt.show()

# %%
corrMatrix = z.corr()
sns.heatmap(corrMatrix, annot = True, vmin=-1, vmax=1, center= 0, cmap= 'coolwarm',linecolor='black')
plt.show()

# %%
corrMatrix = z.corr()
sns.heatmap(corrMatrix, annot = True, vmin=-1, vmax=1, center= 0, cmap= 'coolwarm', linewidths=3, linecolor='black')
plt.show()
